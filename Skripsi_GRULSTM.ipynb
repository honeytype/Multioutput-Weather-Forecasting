# %% [markdown]
# #Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import torch
import torch.nn as nn
from torch.autograd import Variable

# %% [markdown]
# #Reading the Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Membaca file CSV
df = pd.read_csv("/content/drive/MyDrive/TUGAS AKHIR/Skripsi.csv", sep=';', parse_dates=['Tanggal'])

# %%
df
# Out:
#          Tanggal    Tn    Tx    RR  ff_x
# 0     01/07/2020  22,8    33   NaN   3.0
# 1     02/07/2020  23,5  31,2   NaN   5.0
# 2     03/07/2020   NaN  31,7    19   4.0
# 3     04/07/2020  21,2  29,5  32,7   4.0
# 4     05/07/2020  21,4  31,5   NaN   5.0
# ...          ...   ...   ...   ...   ...
# 1463  03/07/2024    23  33,2   NaN  18.0
# 1464  04/07/2024  22,4    33     2   5.0
# 1465  05/07/2024    23  33,2  28,6  12.0
# 1466  06/07/2024    23  30,3   3,4   9.0
# 1467  07/07/2024    22  30,8  39,3   7.0
#
# [1468 rows x 5 columns]

# %%
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/%m/%Y', errors='coerce')

# %%
df.isnull().sum()
# Out:
# Tanggal      0
# Tn         128
# Tx          66
# RR         358
# ff_x         4
# dtype: int64

# %%
# Mengganti koma dengan titik di seluruh kolom kecuali Tanggal agar bisa dikonversi ke Float
for col in df.columns:
    if df[col].dtype == 'object' and col != 'Tanggal':
        df[col] = df[col].str.replace(',', '.', regex=False)

# Konversi semua kolom numerik ke float
numeric_cols = ['Tn', 'Tx', 'RR', 'ff_x']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Mengecek tipe data kolom
print(df.dtypes)
# Out:
# Tanggal    datetime64[ns]
# Tn                float64
# Tx                float64
# RR                float64
# ff_x              float64
# dtype: object

# %%
# Ekstraksi fitur waktu
df['Year'] = df['Tanggal'].dt.year  # Tahun
df['Month'] = df['Tanggal'].dt.month  # Bulan
df['Day'] = df['Tanggal'].dt.day  # Hari

# %%
df
# Out:
#         Tanggal    Tn    Tx    RR  ff_x  Year  Month  Day
# 0    2020-07-01  22.8  33.0   NaN   3.0  2020      7    1
# 1    2020-07-02  23.5  31.2   NaN   5.0  2020      7    2
# 2    2020-07-03   NaN  31.7  19.0   4.0  2020      7    3
# 3    2020-07-04  21.2  29.5  32.7   4.0  2020      7    4
# 4    2020-07-05  21.4  31.5   NaN   5.0  2020      7    5
# ...         ...   ...   ...   ...   ...   ...    ...  ...
# 1463 2024-07-03  23.0  33.2   NaN  18.0  2024      7    3
# 1464 2024-07-04  22.4  33.0   2.0   5.0  2024      7    4
# 1465 2024-07-05  23.0  33.2  28.6  12.0  2024      7    5
# 1466 2024-07-06  23.0  30.3   3.4   9.0  2024      7    6
# 1467 2024-07-07  22.0  30.8  39.3   7.0  2024      7    7
#
# [1468 rows x 8 columns]

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ###Handling Missing Values

# %%
# Memeriksa jumlah missing values di setiap kolom
print(df.isnull().sum())
# Out:
# Tanggal      0
# Tn         128
# Tx          66
# RR         358
# ff_x         4
# Year         0
# Month        0
# Day          0
# dtype: int64

# %%
# # Mengganti nilai 8888 dan kosong dengan NaN, lalu isi setiap nilai NaN dengan forward fill
df.replace(8888, np.nan, inplace=True)

# %%
# def is_invalid(value):
#     return pd.isna(value) or value == 8888

# def fill_with_avg_rr(rr_series):
#     rr_filled = rr_series.copy()

#     for i in range(len(rr_filled)):
#         if is_invalid(rr_filled[i]):
#             # Cari nilai valid di atas
#             prev = i - 1
#             while prev >= 0 and is_invalid(rr_filled[prev]):
#                 prev -= 1

#             # Cari nilai valid di bawah
#             next = i + 1
#             while next < len(rr_filled) and is_invalid(rr_filled[next]):
#                 next += 1

#             prev_value = rr_filled[prev] if prev >= 0 else np.nan
#             next_value = rr_filled[next] if next < len(rr_filled) else np.nan

#             # Imputasi dengan rata-rata dua nilai valid
#             if not pd.isna(prev_value) and not pd.isna(next_value):
#                 rr_filled[i] = (prev_value + next_value) / 2
#             elif not pd.isna(prev_value):
#                 rr_filled[i] = prev_value
#             elif not pd.isna(next_value):
#                 rr_filled[i] = next_value
#             else:
#                 rr_filled[i] = np.nan  # Jika tidak ditemukan nilai valid sama sekali

#     return rr_filled

# %%
df['RR'] = df['RR'].fillna(0)

# 2. Ffill untuk kolom selain RR
df[['Tn', 'Tx', 'ff_x']] = df[['Tn', 'Tx', 'ff_x']].fillna(method='ffill')

# Memeriksa kembali nilai null
print(df.isnull().sum())  # Pastikan tidak ada lagi nilai null
# Out:
# Tanggal    0
# Tn         0
# Tx         0
# RR         0
# ff_x       0
# Year       0
# Month      0
# Day        0
# dtype: int64
# <ipython-input-14-2b3286df6ca3>:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['Tn', 'Tx', 'ff_x']] = df[['Tn', 'Tx', 'ff_x']].fillna(method='ffill')

# %%
df
# Out:
#         Tanggal    Tn    Tx    RR  ff_x  Year  Month  Day
# 0    2020-07-01  22.8  33.0   0.0   3.0  2020      7    1
# 1    2020-07-02  23.5  31.2   0.0   5.0  2020      7    2
# 2    2020-07-03  23.5  31.7  19.0   4.0  2020      7    3
# 3    2020-07-04  21.2  29.5  32.7   4.0  2020      7    4
# 4    2020-07-05  21.4  31.5   0.0   5.0  2020      7    5
# ...         ...   ...   ...   ...   ...   ...    ...  ...
# 1463 2024-07-03  23.0  33.2   0.0  18.0  2024      7    3
# 1464 2024-07-04  22.4  33.0   2.0   5.0  2024      7    4
# 1465 2024-07-05  23.0  33.2  28.6  12.0  2024      7    5
# 1466 2024-07-06  23.0  30.3   3.4   9.0  2024      7    6
# 1467 2024-07-07  22.0  30.8  39.3   7.0  2024      7    7
#
# [1468 rows x 8 columns]

# %% [markdown]
# #EDA

# %%
import matplotlib.pyplot as plt

# Mengatur style default
plt.style.use('default')

# Membuat figure dengan ukuran lebih besar dan 2 baris, 3 kolom
fig, axes = plt.subplots(2, 2, figsize=(14, 8))  # Ukuran figure, 2 baris, 3 kolom

# Plot setiap kolom pada subplot yang berbeda

# Baris pertama (kolom pertama dan kedua)
axes[0, 0].plot(df['Tn'], linewidth=2, color='blue')
axes[0, 0].set_title("Tn - Suhu Minimum")
axes[0, 0].set_xlabel("Date")
axes[0, 0].set_ylabel("Suhu (°C)")
axes[0, 0].grid(False)
axes[0, 0].spines['top'].set_visible(False)
axes[0, 0].spines['right'].set_visible(False)

axes[0, 1].plot(df['Tx'], linewidth=2, color='red')
axes[0, 1].set_title("Tx - Suhu Maksimum")
axes[0, 1].set_xlabel("Date")
axes[0, 1].set_ylabel("Suhu (°C)")
axes[0, 1].grid(False)
axes[0, 1].spines['top'].set_visible(False)
axes[0, 1].spines['right'].set_visible(False)


axes[1, 1].plot(df['RR'], linewidth=2, color='purple')
axes[1, 1].set_title("RR - Curah Hujan")
axes[1, 1].set_xlabel("Date")
axes[1, 1].set_ylabel("Curah Hujan (mm)")
axes[1, 1].grid(False)
axes[1, 1].spines['top'].set_visible(False)
axes[1, 1].spines['right'].set_visible(False)

# Baris terakhir (kolom kelima)
axes[1, 0].plot(df['ff_x'], linewidth=2, color='orange')
axes[1, 0].set_title("ff_x - Kecepatan Angin")
axes[1, 0].set_xlabel("Date")
axes[1, 0].set_ylabel("Kecepatan Angin (km/jam)")
axes[1, 0].grid(False)
axes[1, 0].spines['top'].set_visible(False)
axes[1, 0].spines['right'].set_visible(False)

# Mengatur layout agar lebih rapi
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pastikan kolom 'Bulan' ada
df['Bulan'] = df['Tanggal'].dt.month

sns.set(style="whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

plot_data = [
    ('Tn', 'Sebaran Suhu Minimum (Tn) per Bulan'),
    ('Tx', 'Sebaran Suhu Maksimum (Tx) per Bulan'),
    ('RR', 'Sebaran Curah Hujan (RR) per Bulan'),
    ('ff_x', 'Sebaran Kecepatan Angin (ff_x) per Bulan')
]

for i, (col, title) in enumerate(plot_data):
    sns.boxplot(x='Bulan', y=col, data=df, ax=axes[i], hue='Bulan', palette='Set2', legend=False)
    axes[i].set_title(title)
    axes[i].set_xlabel('Bulan')
    axes[i].set_ylabel(col)
    axes[i].set_xticks(range(0, 12))
    axes[i].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Agu', 'Sep', 'Okt', 'Nov', 'Des'])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Pastikan kolom Quarter sudah ada
df['Quarter'] = df['Tanggal'].dt.to_period('Q')

# --- BOX PLOT per Quarter ---
plt.style.use('default')
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes = axes.flatten()

for i, col in enumerate(['Tn', 'Tx', 'RR', 'ff_x']):
    sns.boxplot(x='Quarter', y=col, data=df, ax=axes[i], palette='Set3')
    axes[i].set_title(f'{col} vs Quarter')
    axes[i].set_xlabel("Kuartal")
    axes[i].set_ylabel(col)
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# --- RATA-RATA per Quarter (Line Plot) ---
df_quarterly = df.groupby('Quarter')[['Tn', 'Tx', 'RR', 'ff_x']].mean()

df_quarterly.plot(marker='o', figsize=(14, 6), linewidth=2, cmap='tab10')
plt.title("Rata-rata Variabel Cuaca per Kuartal")
plt.ylabel("Rata-rata Nilai")
plt.xlabel("Kuartal")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-2966f7328758>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Quarter', y=col, data=df, ax=axes[i], palette='Set3')
# <ipython-input-18-2966f7328758>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Quarter', y=col, data=df, ax=axes[i], palette='Set3')
# <ipython-input-18-2966f7328758>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Quarter', y=col, data=df, ax=axes[i], palette='Set3')
# <ipython-input-18-2966f7328758>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Quarter', y=col, data=df, ax=axes[i], palette='Set3')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pastikan kolom Bulan ada
df['Bulan'] = df['Tanggal'].dt.month

plt.figure(figsize=(14, 7))

# Menggunakan offset untuk menempatkan variabel-variabel pada posisi yang berbeda
offsets = [-0.2, -0.1, 0.1, 0.2]  # Offset untuk menempatkan variabel-variabel secara berurutan

# Plot titik untuk setiap variabel
plt.scatter(df['Bulan'] + offsets[0], df['Tn'], color='blue', label='Tn - Suhu Minimum (°C)', alpha=0.6, s=60)  # Ukuran titik diperbesar
plt.scatter(df['Bulan'] + offsets[1], df['Tx'], color='red', label='Tx - Suhu Maksimum (°C)', alpha=0.6, s=60)  # Ukuran titik diperbesar
plt.scatter(df['Bulan'] + offsets[2], df['RR'], color='purple', label='RR - Curah Hujan (mm)', alpha=0.6, s=60)  # Ukuran titik diperbesar
plt.scatter(df['Bulan'] + offsets[3], df['ff_x'], color='orange', label='ff_x - Kecepatan Angin (km/jam)', alpha=0.6, s=60)  # Ukuran titik diperbesar

# Format sumbu dan tampilan
plt.title('Sebaran Nilai Variabel Cuaca per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Nilai')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                                       'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True, linestyle='--', alpha=0.4)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Menghitung korelasi antar variabel numerik
corr = df[['Tn', 'Tx', 'RR', 'ff_x', 'Year', 'Month', 'Day']].corr()

# Membuat heatmap dari matriks korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1, cbar_kws={'shrink': 0.8})

# Menambahkan judul dan menampilkan plot
plt.title('Heatmap Korelasi Antar Variabel Cuaca')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#      Tanggal    Tn    Tx    RR  ff_x  Year  Month  Day  Bulan Quarter
# 0 2020-07-01  22.8  33.0   0.0   3.0  2020      7    1      7  2020Q3
# 1 2020-07-02  23.5  31.2   0.0   5.0  2020      7    2      7  2020Q3
# 2 2020-07-03  23.5  31.7  19.0   4.0  2020      7    3      7  2020Q3
# 3 2020-07-04  21.2  29.5  32.7   4.0  2020      7    4      7  2020Q3
# 4 2020-07-05  21.4  31.5   0.0   5.0  2020      7    5      7  2020Q3

# %%
df_tanggal = df['Tanggal'].tail(147)

df_tanggal.to_csv('tanggal.csv', index=False)

# %% [markdown]
# #Modelling

# %% [markdown]
# ## Create Function

# %%
def create_sliding_window(data, target_cols, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size][target_cols])
    return np.array(X), np.array(y)

# %%
def split_data(X, y, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    total_len = len(X)

    # Validasi total rasio harus 1.0
    assert abs(train_ratio + val_ratio + test_ratio - 1.0) < 1e-6, "Total rasio harus sama dengan 1.0"

    train_end = int(total_len * train_ratio)
    val_end = train_end + int(total_len * val_ratio)

    X_train, y_train = X[:train_end], y[:train_end]
    X_val, y_val = X[train_end:val_end], y[train_end:val_end]
    X_test, y_test = X[val_end:], y[val_end:]

    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# %% [markdown]
# ## GRU-LSTM Model

# %% [markdown]
# ### Splitting Data

# %%
#Inisialisasi Fitur
features = ['Tn', 'Tx', 'RR', 'ff_x']
target_cols = features  # atau kolom target yang kamu mau prediksi
df = df[features]
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[features])

# Konversi ke DataFrame lagi agar bisa indexing kolom
scaled_df = pd.DataFrame(scaled_data, columns=df[features].columns)

# Gunakan sliding window
window_size = 4  # atau sesuai kebutuhanmu
X, y = create_sliding_window(scaled_df.values, df[features].columns.get_indexer(target_cols), window_size)

# %%
(X_train, y_train), (X_val, y_val), (X_test, y_test) = split_data(X, y, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)

# %%
print("X_train:", X_train.shape)
print("X_val:", X_val.shape)
print("X_test:", X_test.shape)
# Out:
# X_train: (1171, 4, 4)
# X_val: (146, 4, 4)
# X_test: (147, 4, 4)

# %% [markdown]
# ### Data Loader

# %%
from torch.utils.data import DataLoader, TensorDataset

# Pastikan variabel `X_train`, `X_val`, `X_test`, `y_train`, `y_val`, `y_test` sudah tersedia
seq_len = X_train.shape[1]  # Digunakan untuk hitung ukuran Flatten

# Konversi ke tensor
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

# Buat DataLoader
train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=16, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=16)

# %% [markdown]
# ### Define Model

# %%
# import torch
# import torch.nn as nn

# class GRULSTMModel(nn.Module):
#     def __init__(self, input_dim, hidden_dim, output_dim, num_layers=1, dropout=0.3):
#         super(GRULSTMModel, self).__init__()
#         self.gru = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
#         self.lstm = nn.LSTM(hidden_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
#         self.flatten = nn.Flatten()
#         self.fc = nn.Linear(hidden_dim * seq_len, output_dim)  # seq_len harus ditentukan di awal

#     def forward(self, x):
#         out, _ = self.gru(x)
#         out, _ = self.lstm(out)
#         out = self.flatten(out)
#         out = self.fc(out)
#         return out

# %%
import torch
import torch.nn as nn

class GRULSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=1, dropout=0.3):
        super(GRULSTMModel, self).__init__()
        self.gru = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
        self.lstm = nn.LSTM(hidden_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)  # hanya hidden_dim, karena ambil timestep terakhir

    def forward(self, x):
        out, _ = self.gru(x)
        out, _ = self.lstm(out)
        out = out[:, -1, :]  # ambil output di timestep terakhir
        out = self.fc(out)
        return out

# %%
input_dim = X_train.shape[2]
hidden_dim = 128
output_dim = y_train.shape[1]  # jumlah target
num_epochs = 200
patience = 20
best_val_loss = np.inf
wait = 0

model = GRULSTMModel(input_dim, hidden_dim, output_dim)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   warnings.warn(

# %% [markdown]
# ### Train Model

# %%
train_losses = []
val_losses = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            loss = criterion(pred, yb)
            val_loss += loss.item()

    # Rata-rata loss
    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

    # Early Stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        wait = 0
        torch.save(model.state_dict(), "best_model_gru_lstm.pt")
        print("✅ Best model disimpan.")
    else:
        wait += 1
        if wait >= patience:
            print("⛔️ Early stopping triggered.")
            break
# Out:
# Epoch 1/200 | Train Loss: 0.1090 | Val Loss: 0.0729
# ✅ Best model disimpan.
# Epoch 2/200 | Train Loss: 0.0188 | Val Loss: 0.0368
# ✅ Best model disimpan.
# Epoch 3/200 | Train Loss: 0.0170 | Val Loss: 0.0365
# ✅ Best model disimpan.
# Epoch 4/200 | Train Loss: 0.0166 | Val Loss: 0.0357
# ✅ Best model disimpan.
# Epoch 5/200 | Train Loss: 0.0166 | Val Loss: 0.0350
# ✅ Best model disimpan.
# Epoch 6/200 | Train Loss: 0.0163 | Val Loss: 0.0351
# Epoch 7/200 | Train Loss: 0.0162 | Val Loss: 0.0335
# ✅ Best model disimpan.
# Epoch 8/200 | Train Loss: 0.0159 | Val Loss: 0.0338
# Epoch 9/200 | Train Loss: 0.0161 | Val Loss: 0.0330
# ✅ Best model disimpan.
# Epoch 10/200 | Train Loss: 0.0157 | Val Loss: 0.0335
# Epoch 11/200 | Train Loss: 0.0154 | Val Loss: 0.0328
# ✅ Best model disimpan.
# Epoch 12/200 | Train Loss: 0.0153 | Val Loss: 0.0310
# ✅ Best model disimpan.
# Epoch 13/200 | Train Loss: 0.0154 | Val Loss: 0.0313
# Epoch 14/200 | Train Loss: 0.0151 | Val Loss: 0.0311
# Epoch 15/200 | Train Loss: 0.0150 | Val Loss: 0.0322
# Epoch 16/200 | Train Loss: 0.0149 | Val Loss: 0.0306
# ✅ Best model disimpan.
# Epoch 17/200 | Train Loss: 0.0151 | Val Loss: 0.0307
# Epoch 18/200 | Train Loss: 0.0150 | Val Loss: 0.0309
# Epoch 19/200 | Train Loss: 0.0147 | Val Loss: 0.0298
# ✅ Best model disimpan.
# Epoch 20/200 | Train Loss: 0.0147 | Val Loss: 0.0299
# Epoch 21/200 | Train Loss: 0.0147 | Val Loss: 0.0303
# Epoch 22/200 | Train Loss: 0.0145 | Val Loss: 0.0310
# Epoch 23/200 | Train Loss: 0.0148 | Val Loss: 0.0305
# Epoch 24/200 | Train Loss: 0.0152 | Val Loss: 0.0303
# Epoch 25/200 | Train Loss: 0.0145 | Val Loss: 0.0296
# ✅ Best model disimpan.
# Epoch 26/200 | Train Loss: 0.0145 | Val Loss: 0.0292
# ✅ Best model disimpan.
# Epoch 27/200 | Train Loss: 0.0144 | Val Loss: 0.0294
# Epoch 28/200 | Train Loss: 0.0144 | Val Loss: 0.0300
# Epoch 29/200 | Train Loss: 0.0144 | Val Loss: 0.0295
# Epoch 30/200 | Train Loss: 0.0143 | Val Loss: 0.0317
# Epoch 31/200 | Train Loss: 0.0143 | Val Loss: 0.0297
# Epoch 32/200 | Train Loss: 0.0144 | Val Loss: 0.0301
# Epoch 33/200 | Train Loss: 0.0143 | Val Loss: 0.0303
# Epoch 34/200 | Train Loss: 0.0144 | Val Loss: 0.0319
# Epoch 35/200 | Train Loss: 0.0143 | Val Loss: 0.0307
# Epoch 36/200 | Train Loss: 0.0142 | Val Loss: 0.0295
# Epoch 37/200 | Train Loss: 0.0143 | Val Loss: 0.0300
# Epoch 38/200 | Train Loss: 0.0142 | Val Loss: 0.0292
# Epoch 39/200 | Train Loss: 0.0143 | Val Loss: 0.0323
# Epoch 40/200 | Train Loss: 0.0142 | Val Loss: 0.0291
# ✅ Best model disimpan.
# Epoch 41/200 | Train Loss: 0.0141 | Val Loss: 0.0296
# Epoch 42/200 | Train Loss: 0.0141 | Val Loss: 0.0300
# Epoch 43/200 | Train Loss: 0.0142 | Val Loss: 0.0292
# Epoch 44/200 | Train Loss: 0.0140 | Val Loss: 0.0290
# ✅ Best model disimpan.
# Epoch 45/200 | Train Loss: 0.0143 | Val Loss: 0.0305
# Epoch 46/200 | Train Loss: 0.0142 | Val Loss: 0.0295
# Epoch 47/200 | Train Loss: 0.0141 | Val Loss: 0.0301
# Epoch 48/200 | Train Loss: 0.0142 | Val Loss: 0.0291
# Epoch 49/200 | Train Loss: 0.0141 | Val Loss: 0.0303
# Epoch 50/200 | Train Loss: 0.0141 | Val Loss: 0.0281
# ✅ Best model disimpan.
# Epoch 51/200 | Train Loss: 0.0141 | Val Loss: 0.0301
# Epoch 52/200 | Train Loss: 0.0139 | Val Loss: 0.0283
# Epoch 53/200 | Train Loss: 0.0139 | Val Loss: 0.0281
# ✅ Best model disimpan.
# Epoch 54/200 | Train Loss: 0.0140 | Val Loss: 0.0298
# Epoch 55/200 | Train Loss: 0.0146 | Val Loss: 0.0285
# Epoch 56/200 | Train Loss: 0.0139 | Val Loss: 0.0307
# Epoch 57/200 | Train Loss: 0.0138 | Val Loss: 0.0283
# Epoch 58/200 | Train Loss: 0.0140 | Val Loss: 0.0281
# Epoch 59/200 | Train Loss: 0.0139 | Val Loss: 0.0286
# Epoch 60/200 | Train Loss: 0.0139 | Val Loss: 0.0284
# Epoch 61/200 | Train Loss: 0.0139 | Val Loss: 0.0297
# Epoch 62/200 | Train Loss: 0.0139 | Val Loss: 0.0300
# Epoch 63/200 | Train Loss: 0.0139 | Val Loss: 0.0288
# Epoch 64/200 | Train Loss: 0.0139 | Val Loss: 0.0280
# ✅ Best model disimpan.
# Epoch 65/200 | Train Loss: 0.0138 | Val Loss: 0.0282
# Epoch 66/200 | Train Loss: 0.0139 | Val Loss: 0.0284
# Epoch 67/200 | Train Loss: 0.0138 | Val Loss: 0.0290
# Epoch 68/200 | Train Loss: 0.0138 | Val Loss: 0.0279
# ✅ Best model disimpan.
# Epoch 69/200 | Train Loss: 0.0138 | Val Loss: 0.0290
# Epoch 70/200 | Train Loss: 0.0137 | Val Loss: 0.0276
# ✅ Best model disimpan.
# Epoch 71/200 | Train Loss: 0.0141 | Val Loss: 0.0289
# Epoch 72/200 | Train Loss: 0.0138 | Val Loss: 0.0279
# Epoch 73/200 | Train Loss: 0.0138 | Val Loss: 0.0281
# Epoch 74/200 | Train Loss: 0.0137 | Val Loss: 0.0297
# Epoch 75/200 | Train Loss: 0.0138 | Val Loss: 0.0287
# Epoch 76/200 | Train Loss: 0.0137 | Val Loss: 0.0288
# Epoch 77/200 | Train Loss: 0.0137 | Val Loss: 0.0288
# Epoch 78/200 | Train Loss: 0.0138 | Val Loss: 0.0298
# Epoch 79/200 | Train Loss: 0.0137 | Val Loss: 0.0283
# Epoch 80/200 | Train Loss: 0.0138 | Val Loss: 0.0284
# Epoch 81/200 | Train Loss: 0.0142 | Val Loss: 0.0281
# Epoch 82/200 | Train Loss: 0.0137 | Val Loss: 0.0294
# Epoch 83/200 | Train Loss: 0.0137 | Val Loss: 0.0294
# Epoch 84/200 | Train Loss: 0.0138 | Val Loss: 0.0283
# Epoch 85/200 | Train Loss: 0.0136 | Val Loss: 0.0278
# Epoch 86/200 | Train Loss: 0.0138 | Val Loss: 0.0275
# ✅ Best model disimpan.
# Epoch 87/200 | Train Loss: 0.0139 | Val Loss: 0.0284
# Epoch 88/200 | Train Loss: 0.0137 | Val Loss: 0.0294
# Epoch 89/200 | Train Loss: 0.0137 | Val Loss: 0.0291
# Epoch 90/200 | Train Loss: 0.0136 | Val Loss: 0.0290
# Epoch 91/200 | Train Loss: 0.0137 | Val Loss: 0.0280
# Epoch 92/200 | Train Loss: 0.0137 | Val Loss: 0.0277
# Epoch 93/200 | Train Loss: 0.0137 | Val Loss: 0.0279
# Epoch 94/200 | Train Loss: 0.0136 | Val Loss: 0.0283
# Epoch 95/200 | Train Loss: 0.0137 | Val Loss: 0.0278
# Epoch 96/200 | Train Loss: 0.0136 | Val Loss: 0.0280
# Epoch 97/200 | Train Loss: 0.0137 | Val Loss: 0.0279
# Epoch 98/200 | Train Loss: 0.0138 | Val Loss: 0.0280
# Epoch 99/200 | Train Loss: 0.0136 | Val Loss: 0.0297
# Epoch 100/200 | Train Loss: 0.0136 | Val Loss: 0.0283
# Epoch 101/200 | Train Loss: 0.0136 | Val Loss: 0.0282
# Epoch 102/200 | Train Loss: 0.0137 | Val Loss: 0.0278
# Epoch 103/200 | Train Loss: 0.0136 | Val Loss: 0.0280
# Epoch 104/200 | Train Loss: 0.0135 | Val Loss: 0.0274
# ✅ Best model disimpan.
# Epoch 105/200 | Train Loss: 0.0135 | Val Loss: 0.0285
# Epoch 106/200 | Train Loss: 0.0137 | Val Loss: 0.0288
# Epoch 107/200 | Train Loss: 0.0136 | Val Loss: 0.0283
# Epoch 108/200 | Train Loss: 0.0135 | Val Loss: 0.0284
# Epoch 109/200 | Train Loss: 0.0135 | Val Loss: 0.0283
# Epoch 110/200 | Train Loss: 0.0136 | Val Loss: 0.0279
# Epoch 111/200 | Train Loss: 0.0137 | Val Loss: 0.0274
# ✅ Best model disimpan.
# Epoch 112/200 | Train Loss: 0.0135 | Val Loss: 0.0280
# Epoch 113/200 | Train Loss: 0.0137 | Val Loss: 0.0286
# Epoch 114/200 | Train Loss: 0.0136 | Val Loss: 0.0277
# Epoch 115/200 | Train Loss: 0.0136 | Val Loss: 0.0288
# Epoch 116/200 | Train Loss: 0.0136 | Val Loss: 0.0281
# Epoch 117/200 | Train Loss: 0.0136 | Val Loss: 0.0269
# ✅ Best model disimpan.
# Epoch 118/200 | Train Loss: 0.0135 | Val Loss: 0.0274
# Epoch 119/200 | Train Loss: 0.0136 | Val Loss: 0.0288
# Epoch 120/200 | Train Loss: 0.0137 | Val Loss: 0.0295
# Epoch 121/200 | Train Loss: 0.0136 | Val Loss: 0.0281
# Epoch 122/200 | Train Loss: 0.0135 | Val Loss: 0.0273
# Epoch 123/200 | Train Loss: 0.0137 | Val Loss: 0.0275
# Epoch 124/200 | Train Loss: 0.0136 | Val Loss: 0.0284
# Epoch 125/200 | Train Loss: 0.0135 | Val Loss: 0.0286
# Epoch 126/200 | Train Loss: 0.0135 | Val Loss: 0.0276
# Epoch 127/200 | Train Loss: 0.0136 | Val Loss: 0.0270
# Epoch 128/200 | Train Loss: 0.0136 | Val Loss: 0.0272
# Epoch 129/200 | Train Loss: 0.0136 | Val Loss: 0.0280
# Epoch 130/200 | Train Loss: 0.0136 | Val Loss: 0.0276
# Epoch 131/200 | Train Loss: 0.0137 | Val Loss: 0.0278
# Epoch 132/200 | Train Loss: 0.0137 | Val Loss: 0.0277
# Epoch 133/200 | Train Loss: 0.0137 | Val Loss: 0.0278
# Epoch 134/200 | Train Loss: 0.0135 | Val Loss: 0.0287
# Epoch 135/200 | Train Loss: 0.0137 | Val Loss: 0.0286
# Epoch 136/200 | Train Loss: 0.0136 | Val Loss: 0.0286
# Epoch 137/200 | Train Loss: 0.0136 | Val Loss: 0.0273
# ⛔️ Early stopping triggered.

# %%
# Load best model
model.load_state_dict(torch.load("best_model_gru_lstm.pt"))
model.eval()

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
with torch.no_grad():
    y_pred_tensor = model(X_test_tensor)
    y_pred = y_pred_tensor.numpy()

# %% [markdown]
# ### Evaluation Model

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    epsilon = 1e-8  # untuk mencegah pembagian nol
    return np.mean(np.abs((y_true - y_pred) / (y_true + epsilon))) * 100

# Jika prediksi & ground truth masih dalam skala hasil scaling:
# Gabungkan dengan array kosong agar inverse_transform bisa dilakukan
dummy = np.zeros((len(y_test), scaler.n_features_in_))
dummy[:, df.columns.get_indexer(target_cols)] = y_test
y_test_inv = scaler.inverse_transform(dummy)[:, df.columns.get_indexer(target_cols)]

dummy_pred = np.zeros((len(y_pred), scaler.n_features_in_))
dummy_pred[:, df.columns.get_indexer(target_cols)] = y_pred
y_pred_inv = scaler.inverse_transform(dummy_pred)[:, df.columns.get_indexer(target_cols)]

# Evaluasi
# Inisialisasi dictionary untuk menyimpan metrik per target kolom
mse_dict = {}
rmse_dict = {}
mae_dict = {}

print("📊 Evaluasi pada Test Set:")
for i, var in enumerate(target_cols):
    mse_val = mean_squared_error(y_test_inv[:, i], y_pred_inv[:, i])
    rmse_val = np.sqrt(mse_val)
    mae_val = mean_absolute_error(y_test_inv[:, i], y_pred_inv[:, i])

    # Simpan ke dalam dictionary
    mse_dict[var] = mse_val
    rmse_dict[var] = rmse_val
    mae_dict[var] = mae_val

    # Cetak hasil evaluasi
    print(f"{var} - MSE: {mse_val:.2f}, RMSE: {rmse_val:.2f}, MAE: {mae_val:.2f}")
# Out:
# 📊 Evaluasi pada Test Set:
# Tn - MSE: 0.77, RMSE: 0.88, MAE: 0.72
# Tx - MSE: 1.41, RMSE: 1.19, MAE: 0.90
# RR - MSE: 634.42, RMSE: 25.19, MAE: 17.62
# ff_x - MSE: 12.75, RMSE: 3.57, MAE: 2.58

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

# Visualisasi GRU-LSTM - Satu gambar per variabel
for i, var in enumerate(target_cols):
    plt.figure(figsize=(10, 6))
    plt.plot(y_test_inv[:, i], label='Actual', color='blue', linewidth=2)
    plt.plot(y_pred_inv[:, i], label='Predicted', color='red', linewidth=2)
    plt.title(f'GRU-LSTM Forecast vs Actual: {var}')
    plt.xlabel('Time Step')
    plt.ylabel(var)

    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(train_losses, label='Training Loss', linewidth=2)
plt.plot(val_losses, label='Validation Loss', linewidth=2)
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tabel Evaluasi

# %%
# import matplotlib.pyplot as plt

# plt.rcParams['font.family'] = 'serif'
# for i, var in enumerate(target_cols):
#     # Membuat figure dan satu subplot untuk setiap target
#     fig, ax = plt.subplots(figsize=(10, 6))

#     # Plot data aktual dan hasil prediksi dari masing-masing model
#     ax.plot(y_test_inv[:, i], label='Actual', color='blue', linewidth=2)
#     ax.plot(y_pred_inv[:, i], label='GRU-LSTM', color='red', linewidth=2)
#     ax.plot(y_pred_gru_inv[:, i], label='GRU', color='green', linewidth=2)
#     ax.plot(y_pred_lstm_inv[:, i], label='LSTM', color='orange', linewidth=2)

#     # Menambahkan judul dan legenda
#     ax.set_title(f'{var} - All Models Forecast vs Actual')
#     ax.legend()

#     # Menghilangkan grid dan border
#     ax.grid(False)
#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)

#     # Menampilkan plot
#     plt.tight_layout()
#     plt.show()

# %%
# summary_df = pd.DataFrame({
#     'Variabel': target_cols,

#     'MSE_GRULSTM': [mse_dict[var] for var in target_cols],
#     'RMSE_GRULSTM': [rmse_dict[var] for var in target_cols],
#     'MAE_GRULSTM': [mae_dict[var] for var in target_cols],

#     'MSE_GRU': [mse_gru_dict[var] for var in target_cols],
#     'RMSE_GRU': [rmse_gru_dict[var] for var in target_cols],
#     'MAE_GRU': [mae_gru_dict[var] for var in target_cols],

#     'MSE_LSTM': [mse_lstm_dict[var] for var in target_cols],
#     'RMSE_LSTM': [rmse_lstm_dict[var] for var in target_cols],
#     'MAE_LSTM': [mae_lstm_dict[var] for var in target_cols],
# })

# summary_df

# %%
# # Ubah ke long format dulu
# summary_melted = summary_df.melt(id_vars='Variabel', var_name='Metric_Model', value_name='Value')

# # Pisahkan 'Metric' dan 'Model' dari kolom 'Metric_Model'
# summary_melted[['Metric', 'Model']] = summary_melted['Metric_Model'].str.extract(r'(\w+)_([\w]+)')

# # Pivot agar Model jadi kolom, Variabel jadi kolom, dan Metric jadi baris
# summary_pivoted = summary_melted.pivot_table(index=['Metric', 'Model'], columns='Variabel', values='Value')

# # Opsional: rapikan nama kolom
# summary_pivoted = summary_pivoted.reset_index()

# summary_pivoted

# %%
# summary_pivoted.to_csv("/content/drive/MyDrive/TUGAS AKHIR/Evaluasi Tabel.csv", index=False, sep=";", decimal=',')

# %% [markdown]
# ## Save Model

# %%
# Buat dataframe untuk y_true
df_true = pd.DataFrame(y_test_inv, columns=[f"{col}_true" for col in target_cols])
# Dataframe untuk masing-masing prediksi
df_pred_grulstm = pd.DataFrame(y_pred_inv, columns=[f"{col}_pred_grulstm" for col in target_cols])

# Gabungkan semua
df_all_preds = pd.concat([df_true, df_pred_grulstm], axis=1)

# Simpan ke CSV
save_path_preds = "/content/drive/MyDrive/TUGAS AKHIR/y_true_vs_pred_GRULSTM.csv"
df_all_preds.to_csv(save_path_preds, index=False, sep=";", decimal=',')

print(f"✅ DataFrame semua prediksi berhasil disimpan di: {save_path_preds}")
# Out:
# ✅ DataFrame semua prediksi berhasil disimpan di: /content/drive/MyDrive/TUGAS AKHIR/y_true_vs_pred_GRULSTM.csv

# %%
# Tentukan jumlah epoch terpendek
min_len = min(len(train_losses), len(val_losses))

# Buat DataFrame dari losses
df_losses = pd.DataFrame({
    "epoch": list(range(1, min_len + 1)),
    "train_loss_grulstm": train_losses[:min_len],
    "val_loss_grulstm": val_losses[:min_len],
    # "train_loss_gru": train_losses_gru[:min_len],
    # "val_loss_gru": val_losses_gru[:min_len],
    # "train_loss_lstm": train_losses_lstm[:min_len],
    # "val_loss_lstm": val_losses_lstm[:min_len],
})

# Simpan ke CSV
save_path_losses = "/content/drive/MyDrive/TUGAS AKHIR/losses_GRULSTM_models.csv"
df_losses.to_csv(save_path_losses, index=False, sep=";", decimal=',')

print(f"✅ DataFrame loss semua model berhasil disimpan di: {save_path_losses}")
# Out:
# ✅ DataFrame loss semua model berhasil disimpan di: /content/drive/MyDrive/TUGAS AKHIR/losses_GRULSTM_models.csv

# %%
# Path direktori penyimpanan
save_path = "/content/drive/MyDrive/TUGAS AKHIR/"

# Simpan model GRU-LSTM (gabungan)
torch.save(model.state_dict(), save_path + "model_grulstm terbaik.pth")

# # Simpan model GRU saja
# torch.save(model_gru.state_dict(), save_path + "model_gru1.pth")

# # Simpan model LSTM saja
# torch.save(model_lstm.state_dict(), save_path + "model_lstm1.pth")

print("✅ Semua model berhasil disimpan.")
# Out:
# ✅ Semua model berhasil disimpan.
